# %% [markdown]
# # NLP Lab: Language Models
#
# In this lab, we will build the main components of the GPT-2 model and train a small model on poems by Victor Hugo.
#
# The questions are included in this notebook. To run the training, you will need to modify the `gpt_single_head.py` file, which is also available in the Git repository.
#
# ## Data
#
# The training data consists of a collection of poems by Victor Hugo, sourced from [gutenberg.org](https://www.gutenberg.org/). The dataset is available in the `data` directory.
#
# To reduce model complexity, we will model the text at the character level. Typically, language models process sequences of subwords using [tokenizers](https://huggingface.co/docs/transformers/tokenizer_summary) such as BPE, SentencePiece, or WordPiece.
#
# #### Questions:
# - Using [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter), display the number of unique characters in the text and the frequency of each character.

# %%
import collections

with open('data/hugo_contemplations.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f'Number of characters in the file: {len(text)}')
# Out:
# Number of characters in the file: 285222

# %%
chars = collections.Counter(text)
size = len(chars)
print(size)
# Out:
# 101

# %%
print (f'Number of characters: {sum(chars.values())}')
print (f'{size} unique characters')
print (chars)
# Out:
# Number of characters: 285222
# 101 unique characters
# Counter({' ': 49127, 'e': 30253, 's': 17987, 'u': 14254, 'r': 14223, 't': 14071, 'a': 14048, 'n': 13725, 'i': 12828, 'o': 12653, 'l': 11638, '\n': 8102, 'm': 6495, 'd': 6375, ',': 6077, 'c': 5074, 'p': 4206, "'": 3820, 'v': 3492, 'é': 2943, 'b': 2783, 'f': 2772, 'h': 2221, 'q': 1956, 'g': 1790, '.': 1420, 'x': 1154, 'L': 1147, '!': 1121, 'E': 1074, ';': 1043, '-': 1020, 'j': 890, 'D': 764, 'è': 725, 'à': 706, 'y': 660, 'I': 627, 'ê': 605, 'C': 593, 'S': 545, 'A': 530, 'Q': 503, 'z': 482, 'J': 471, 'O': 450, 'T': 441, 'P': 435, '?': 388, 'V': 383, 'â': 381, 'N': 362, 'M': 344, 'ù': 298, ':': 294, 'R': 240, 'î': 214, 'U': 208, 'ô': 159, 'X': 150, '1': 146, 'H': 116, 'F': 114, '5': 111, '8': 93, 'B': 78, '«': 74, 'É': 70, '»': 69, 'G': 67, '4': 64, 'û': 62, '3': 47, 'ç': 34, 'À': 33, 'ë': 32, 'ï': 31, '2': 30, '·': 26, 'Ê': 24, '6': 23, '7': 23, 'Ô': 19, '9': 19, 'È': 11, 'k': 10, '0': 10, '_': 8, 'Z': 7, 'Æ': 4, '[': 4, ']': 4, 'w': 3, 'K': 3, 'Y': 3, 'Ë': 2, '(': 2, ')': 2, 'Â': 2, 'Î': 1, 'W': 1})

# %% [markdown]
# ### Encoding / Decoding
#
# To transform the text into a vector for the neural network, each character must be encoded as an integer.
#
# The following functions perform the encoding and decoding of characters:

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: transform a string into a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: transform a list of integers into a string


# test that your encoder/decoder is coherent
testString = "\nDemain, dès l'aube"
assert decode(encode (testString)) ==  testString # raises an error if the condition is false

# %% [markdown]
# ### Train/Validation Split
#
# Since the goal is to predict poems, the lines should not be shuffled randomly. Instead, we must preserve the order of the lines in the text and take only the first 90% for training, while using the remaining 10% to monitor learning.
#
# #### Questions:
# - Split the data into `train_data` (90%) and `val_data` (10%) using slicing on the dataset.

# %%
#!pip install torch
import torch
# Train and validation splits
data = torch.tensor(encode(text), dtype=torch.long)
# first 90% will be train, rest val

# %%
split_idx = int(0.9 * len(data))
train_data = data[:split_idx]  # First 90%
val_data = data[split_idx:]    # Remaining 10%

# %%
print(f"Total data length: {len(data)}")
print(f"Training data length: {len(train_data)}")
print(f"Validation data length: {len(val_data)}")
# Out:
# Total data length: 285222
# Training data length: 256699
# Validation data length: 28523

# %% [markdown]
# ### Context
#
# The language model has a parameter that defines the maximum context size to consider when predicting the next character. This context is called `block_size`. The training data consists of sequences of consecutive characters, randomly sampled from the training set, with a length of `block_size`.
#
# If the starting character of the sequence is `i`, then the context sequence is:
# ```python
# x = data[i:i+block_size]
# ```
# And the target value to predict at each position in the context is the next character:
# ```python
# y = data[i+1:i+block_size+1]
# ```

# %%
block_size = 8

i  = torch.randint(len(data) - block_size, (1,))
print (i)
x = train_data[i:i+block_size]
y = train_data[i+1:i+1+block_size]
# Out:
# tensor([120771])

# %%
for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print (f'context is >{decode(context.tolist())}< target is >{decode([target.tolist()])}<')
# Out:
# context is >a< target is >n<
# context is >an< target is >s<
# context is >ans< target is > <
# context is >ans < target is >l<
# context is >ans l< target is >e<
# context is >ans le< target is >s<
# context is >ans les< target is > <
# context is >ans les < target is >r<

# %% [markdown]
# ### Defining Batches
#
# The training batches consist of multiple character sequences randomly sampled from `train_data`. To randomly select a sequence for the batch, we need to randomly pick a starting point in `train_data` and extract the following `block_size` characters. When selecting the starting point, ensure that there are enough characters remaining after it to form a full sequence of `block_size` characters.
#
# #### Questions:
# - Create the batches `x` by selecting `batch_size` sequences of length `block_size` starting from a randomly chosen index `i`. Stack the examples using `torch.stack`.
# - Create the batches `y` by adding the next character following each sequence in `x`. Stack the examples using `torch.stack`.

# %%
batch_size = 4
torch.manual_seed(2023)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    
    # Randomly pick batch_size starting indices => ensuring enough characters remain
    starting_points = torch.randint(len(data) - block_size - 1, (batch_size,))

    # Extract sequences of length block_size
    x = torch.stack([data[i : i + block_size] for i in starting_points])

    # extract corresponding target characters (shifted by one position)
    y = torch.stack([data[i + 1 : i + block_size + 1] for i in starting_points])
    
    # send data and target to device
    x, y = x.to(device), y.to(device)
    return x, y

# %% [markdown]
# ### First Model: A Bigram Model
#
# The first model we will implement is a bigram model. It predicts the next character based only on the current character. This model can be stored in a simple matrix: for each character (row), we store the probability distribution over all possible next characters (columns). This can be implemented using a simple [`Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html) layer in PyTorch.
#
# #### Questions:
# - In the constructor, define an Embedding layer of size `vocab_size × vocab_size`.
# - In the `forward` method, apply the embedding layer to the batch of indices (`x`).
# - In the `forward` method, define the loss as `cross_entropy` between the predictions and the target (`y`).

# %%
import torch.nn as nn
import torch.nn.functional as F

# use a gpu if we have one
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # we use a simple vocab_size times vocab_size tensor to store the probabilities 
        # of each token given a single token as context in nn.Embedding
        # Define an embedding layer of size (vocab_size, vocab_size)
        self.embedding = nn.Embedding(vocab_size, vocab_size)
        
    def forward(self, idx, targets=None):

        # idx and targets are both (Batch,Time) tensor of integers
        # apply the embedding layer to get logits
        logits = self.embedding(idx)  # shape = (Batch, Time, Channels), where Channels = vocab_size
   
        # don't compute loss if we don't have targets
        if targets is None:
            loss = None
        else:
            # change the shape of the logits and target to match what is needed for CrossEntropyLoss
            # reshape: (Batch*Time, Vocab) and (Batch*Time)
            # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
            Batch, Time, Channels = logits.shape
            logits = logits.view(Batch*Time, Channels)
            targets = targets.view(Batch*Time)
            
            # negative log likelihood between prediction and target
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, Vocab)
            # apply softmax to get probabilities
            probs = nn.functional.softmax(logits, dim=-1) # (B, vocab)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel(size)
# send the model to device
m = model.to(device)

# %% [markdown]
# ### Model Before Training
#
# At this stage, the model has not yet been trained—it has only been initialized. However, we can already compute the loss on a random batch. Since the weights are initialized with a normal distribution \( N(0,1) \) for each dimension, the expected loss after initialization should be close to `-ln(1/vocab_size)`, as the entropy is maximal.

# %%
import math
xb, yb = get_batch('train')
logits, loss = m(xb, yb)
print (logits.shape)
print (f'Expected loss {-math.log(1.0/size)}')
print (f'Computed loss {loss}')
# Out:
# torch.Size([32, 101])
# Expected loss 4.61512051684126
# Computed loss 5.081887245178223

# %% [markdown]
# ### Using the Model for Prediction
#
# To use the model for prediction, we need to provide an initial character to start the sequence—this is called the prompt. In our case, we can initialize the generation with the newline character (`\n`) to start a new sentence.
#
# #### Questions:
# - Create a prompt as a tensor of size `(1,1)` containing the integer corresponding to the character `\n`.
# - Generate a sequence of 100 characters from this prompt using the functions `m.generate` and `decode`.
# - How does the generated sentence look?

# %%
print (encode(['\n']))
# Out:
# [3]

# %%
# get encoded token for '\n' and wrap it in (1,1) tensor
prompt = torch.tensor([[encode('\n')[0]]], dtype=torch.long).to(device)

# a sequence of 100 new characters
generated_sequence = m.generate(prompt, max_new_tokens=100)

print(decode(generated_sequence[0].tolist()))
# Out:
# wG,aÈ5Szg)cByèÂSP5ufZufcXEméÊ7WVvàxËè.Cà)ëDS](_0VHd-AÀIzÂTêêôô»:ibk'BÈTT4ïFïNê5·q»Uh.V]VîGP7)X[Pg(uË

# %% [markdown]
# ### Training
#
# For training, we use the [AdamW](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html) optimizer with a learning rate of `1e-3`. Each training iteration consists of the following steps:
#
# - Generate a batch
# - Apply the neural network (forward pass) and compute the loss: `model(xb, yb)`
# - Compute the gradient (after resetting accumulated gradients): `loss.backward()`
# - Update the parameters: `optimizer.step()`

# %%
max_iters = 10000 #total number of iterations
batch_size = 4  # number of sequences per batch
eval_interval = 10 # how often we evaluate and print the loss
learning_rate = 1e-3 # learning rate for optimization
eval_iters = 20  # number of batches to estimate loss

@torch.no_grad() # no gradient is computed here, disables gradient computation (no training updates here)
def estimate_loss():
    """ Estimate the loss on eval_iters batches of train and val sets."""
    out = {}
    model.eval() # switches the model to evaluation mode (disables dropout if present)
    for split in ['train', 'val']:  # Loop over both datasets
        losses = torch.zeros(eval_iters) # initializes a tensor to store multiple loss values (for averaging later)
        for k in range(eval_iters): # runs 20 batches (eval_iters) to compute an average loss
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean() # compute mean loss for that dataset
    model.train()
    return out  # returns a dictionary { 'train': train_loss, 'val': val_loss }.

# re-create the model (fresh start)
model = BigramLanguageModel(size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)  # model.parameters(): Tells the optimizer which parameters (weights) to update.

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 5.1548, val loss 5.1154
# step 10: train loss 5.1073, val loss 5.1108
# step 20: train loss 5.1480, val loss 5.1892
# step 30: train loss 5.0843, val loss 5.1801
# step 40: train loss 5.0944, val loss 5.1322
# step 50: train loss 5.0478, val loss 5.0665
# step 60: train loss 5.0250, val loss 4.9836
# step 70: train loss 5.0174, val loss 5.1053
# step 80: train loss 5.0916, val loss 5.1336
# step 90: train loss 5.0801, val loss 5.0802
# step 100: train loss 5.0249, val loss 4.9849
# step 110: train loss 4.9761, val loss 5.0661
# step 120: train loss 4.9744, val loss 4.9663
# step 130: train loss 4.9325, val loss 5.0718
# step 140: train loss 5.0313, val loss 5.0213
# step 150: train loss 5.0017, val loss 4.9673
# step 160: train loss 5.0335, val loss 5.0641
# step 170: train loss 4.9823, val loss 4.9799
# step 180: train loss 4.9735, val loss 4.9399
# step 190: train loss 4.9044, val loss 5.0003
# step 200: train loss 4.9608, val loss 4.9769
# step 210: train loss 5.0081, val loss 4.9319
# step 220: train loss 4.9927, val loss 4.9667
# step 230: train loss 4.8943, val loss 4.9228
# step 240: train loss 4.9659, val loss 4.9680
# step 250: train loss 4.9302, val loss 4.9799
# step 260: train loss 4.8703, val loss 4.9963
# step 270: train loss 4.9350, val loss 4.9160
# step 280: train loss 4.9174, val loss 4.8944
# step 290: train loss 4.9283, val loss 4.9572
# step 300: train loss 4.8830, val loss 4.9270
# step 310: train loss 4.9395, val loss 4.8658
# step 320: train loss 4.8742, val loss 4.8887
# step 330: train loss 4.8310, val loss 4.9235
# step 340: train loss 4.8206, val loss 4.8315
# step 350: train loss 4.7987, val loss 4.8568
# step 360: train loss 4.8004, val loss 4.8318
# step 370: train loss 4.7960, val loss 4.8480
# step 380: train loss 4.8530, val loss 4.8300
# step 390: train loss 4.8269, val loss 4.8185
# step 400: train loss 4.7883, val loss 4.8303
# step 410: train loss 4.7766, val loss 4.7857
# step 420: train loss 4.7974, val loss 4.7479
# step 430: train loss 4.7969, val loss 4.7938
# step 440: train loss 4.7612, val loss 4.7967
# step 450: train loss 4.7612, val loss 4.7806
# step 460: train loss 4.7597, val loss 4.8339
# step 470: train loss 4.6947, val loss 4.7916
# step 480: train loss 4.6835, val loss 4.7391
# step 490: train loss 4.7677, val loss 4.7068
# step 500: train loss 4.6469, val loss 4.7552
# step 510: train loss 4.7223, val loss 4.7127
# step 520: train loss 4.6744, val loss 4.6953
# step 530: train loss 4.6941, val loss 4.7892
# step 540: train loss 4.6334, val loss 4.6489
# step 550: train loss 4.6663, val loss 4.7024
# step 560: train loss 4.5823, val loss 4.6772
# step 570: train loss 4.6560, val loss 4.6722
# step 580: train loss 4.6597, val loss 4.7201
# step 590: train loss 4.6900, val loss 4.6278
# step 600: train loss 4.6752, val loss 4.6283
# step 610: train loss 4.6766, val loss 4.6645
# step 620: train loss 4.5850, val loss 4.6193
# step 630: train loss 4.6174, val loss 4.6225
# step 640: train loss 4.6064, val loss 4.6080
# step 650: train loss 4.6302, val loss 4.6295
# step 660: train loss 4.5502, val loss 4.6654
# step 670: train loss 4.6170, val loss 4.5524
# step 680: train loss 4.6234, val loss 4.6740
# step 690: train loss 4.6559, val loss 4.5928
# step 700: train loss 4.5474, val loss 4.6052
# step 710: train loss 4.5510, val loss 4.6114
# step 720: train loss 4.5480, val loss 4.5794
# step 730: train loss 4.5565, val loss 4.5849
# step 740: train loss 4.5713, val loss 4.5921
# step 750: train loss 4.5014, val loss 4.5292
# step 760: train loss 4.5529, val loss 4.5794
# step 770: train loss 4.5073, val loss 4.5877
# step 780: train loss 4.4647, val loss 4.4718
# step 790: train loss 4.4568, val loss 4.5301
# step 800: train loss 4.4348, val loss 4.4589
# step 810: train loss 4.5267, val loss 4.5211
# step 820: train loss 4.4989, val loss 4.5146
# step 830: train loss 4.4740, val loss 4.5365
# step 840: train loss 4.4354, val loss 4.4736
# step 850: train loss 4.4712, val loss 4.4700
# step 860: train loss 4.4117, val loss 4.5181
# step 870: train loss 4.4818, val loss 4.4237
# step 880: train loss 4.4663, val loss 4.4776
# step 890: train loss 4.4660, val loss 4.4900
# step 900: train loss 4.3869, val loss 4.4539
# step 910: train loss 4.4239, val loss 4.4845
# step 920: train loss 4.4330, val loss 4.4618
# step 930: train loss 4.3662, val loss 4.4143
# step 940: train loss 4.3902, val loss 4.4042
# step 950: train loss 4.4436, val loss 4.4534
# step 960: train loss 4.3600, val loss 4.4086
# step 970: train loss 4.3414, val loss 4.3925
# step 980: train loss 4.4144, val loss 4.4320
# step 990: train loss 4.3870, val loss 4.4044
# step 1000: train loss 4.3376, val loss 4.3619
# step 1010: train loss 4.3618, val loss 4.3596
# step 1020: train loss 4.3072, val loss 4.3356
# step 1030: train loss 4.3120, val loss 4.3834
# step 1040: train loss 4.2498, val loss 4.3277
# step 1050: train loss 4.2942, val loss 4.2963
# step 1060: train loss 4.3086, val loss 4.2997
# step 1070: train loss 4.3151, val loss 4.3564
# step 1080: train loss 4.2660, val loss 4.3247
# step 1090: train loss 4.2221, val loss 4.3779
# step 1100: train loss 4.2023, val loss 4.2958
# step 1110: train loss 4.2661, val loss 4.3562
# step 1120: train loss 4.2748, val loss 4.3036
# step 1130: train loss 4.2397, val loss 4.2940
# step 1140: train loss 4.3073, val loss 4.2523
# step 1150: train loss 4.2894, val loss 4.2481
# step 1160: train loss 4.3057, val loss 4.3226
# step 1170: train loss 4.2515, val loss 4.2418
# step 1180: train loss 4.2785, val loss 4.2588
# step 1190: train loss 4.2122, val loss 4.2916
# step 1200: train loss 4.2171, val loss 4.2755
# step 1210: train loss 4.2050, val loss 4.3336
# step 1220: train loss 4.1460, val loss 4.2221
# step 1230: train loss 4.2179, val loss 4.2329
# step 1240: train loss 4.1925, val loss 4.2305
# step 1250: train loss 4.1415, val loss 4.1754
# step 1260: train loss 4.1427, val loss 4.2556
# step 1270: train loss 4.1778, val loss 4.2168
# step 1280: train loss 4.1624, val loss 4.1181
# step 1290: train loss 4.1599, val loss 4.2137
# step 1300: train loss 4.1515, val loss 4.2350
# step 1310: train loss 4.1617, val loss 4.1882
# step 1320: train loss 4.1601, val loss 4.1127
# step 1330: train loss 4.1372, val loss 4.1719
# step 1340: train loss 4.0674, val loss 4.1301
# step 1350: train loss 4.1637, val loss 4.2015
# step 1360: train loss 4.1056, val loss 4.1469
# step 1370: train loss 4.0609, val loss 4.2146
# step 1380: train loss 4.0514, val loss 4.1243
# step 1390: train loss 4.1155, val loss 4.1855
# step 1400: train loss 4.0703, val loss 4.1794
# step 1410: train loss 4.0776, val loss 4.1568
# step 1420: train loss 4.0471, val loss 4.0916
# step 1430: train loss 4.0971, val loss 4.0999
# step 1440: train loss 3.9918, val loss 4.1206
# step 1450: train loss 4.0558, val loss 4.1189
# step 1460: train loss 4.1132, val loss 4.0750
# step 1470: train loss 4.0529, val loss 4.1299
# step 1480: train loss 4.1120, val loss 4.1371
# step 1490: train loss 4.0275, val loss 4.0472
# step 1500: train loss 4.0040, val loss 4.1227
# step 1510: train loss 3.9757, val loss 4.0741
# step 1520: train loss 3.9273, val loss 4.0678
# step 1530: train loss 4.0158, val loss 4.0393
# step 1540: train loss 3.9899, val loss 4.1544
# step 1550: train loss 4.0161, val loss 4.0733
# step 1560: train loss 4.0216, val loss 4.0167
# step 1570: train loss 3.9597, val loss 4.0043
# step 1580: train loss 3.9851, val loss 4.0507
# step 1590: train loss 3.9628, val loss 4.0284
# step 1600: train loss 3.8765, val loss 4.0285
# step 1610: train loss 3.9396, val loss 3.9879
# step 1620: train loss 3.9861, val loss 3.9945
# step 1630: train loss 3.9428, val loss 4.0147
# step 1640: train loss 3.9648, val loss 3.9800
# step 1650: train loss 3.9225, val loss 4.0145
# step 1660: train loss 3.8585, val loss 4.0076
# step 1670: train loss 3.9704, val loss 3.9915
# step 1680: train loss 3.8608, val loss 3.9693
# step 1690: train loss 3.9518, val loss 3.9597
# step 1700: train loss 3.9465, val loss 3.9889
# step 1710: train loss 3.8927, val loss 3.8923
# step 1720: train loss 3.9279, val loss 3.9998
# step 1730: train loss 3.8886, val loss 4.0337
# step 1740: train loss 3.9023, val loss 4.0356
# step 1750: train loss 3.9380, val loss 3.8763
# step 1760: train loss 3.9738, val loss 3.9856
# step 1770: train loss 3.8310, val loss 3.9212
# step 1780: train loss 3.8070, val loss 3.8941
# step 1790: train loss 3.8589, val loss 3.8854
# step 1800: train loss 3.8324, val loss 3.8974
# step 1810: train loss 3.8718, val loss 3.8973
# step 1820: train loss 3.8142, val loss 3.9725
# step 1830: train loss 3.8607, val loss 3.9385
# step 1840: train loss 3.9239, val loss 3.9143
# step 1850: train loss 3.8360, val loss 3.8974
# step 1860: train loss 3.8432, val loss 3.9694
# step 1870: train loss 3.8976, val loss 3.8864
# step 1880: train loss 3.8535, val loss 3.9215
# step 1890: train loss 3.7942, val loss 3.8211
# step 1900: train loss 3.7843, val loss 3.8749
# step 1910: train loss 3.8022, val loss 3.8288
# step 1920: train loss 3.8915, val loss 3.8873
# step 1930: train loss 3.7422, val loss 3.9416
# step 1940: train loss 3.8552, val loss 3.8848
# step 1950: train loss 3.8693, val loss 3.8412
# step 1960: train loss 3.8129, val loss 3.9111
# step 1970: train loss 3.8083, val loss 3.7958
# step 1980: train loss 3.7423, val loss 3.8040
# step 1990: train loss 3.7430, val loss 3.8599
# step 2000: train loss 3.7245, val loss 3.7861
# step 2010: train loss 3.7207, val loss 3.7978
# step 2020: train loss 3.7574, val loss 3.8617
# step 2030: train loss 3.7442, val loss 3.8063
# step 2040: train loss 3.7614, val loss 3.9081
# step 2050: train loss 3.7381, val loss 3.8025
# step 2060: train loss 3.6785, val loss 3.8052
# step 2070: train loss 3.7370, val loss 3.7434
# step 2080: train loss 3.6810, val loss 3.7676
# step 2090: train loss 3.7207, val loss 3.7699
# step 2100: train loss 3.7281, val loss 3.8231
# step 2110: train loss 3.7649, val loss 3.8719
# step 2120: train loss 3.6964, val loss 3.8592
# step 2130: train loss 3.7414, val loss 3.6675
# step 2140: train loss 3.7021, val loss 3.7589
# step 2150: train loss 3.6715, val loss 3.8159
# step 2160: train loss 3.7281, val loss 3.7432
# step 2170: train loss 3.7213, val loss 3.8545
# step 2180: train loss 3.6418, val loss 3.7732
# step 2190: train loss 3.6457, val loss 3.7091
# step 2200: train loss 3.6838, val loss 3.8309
# step 2210: train loss 3.6225, val loss 3.7233
# step 2220: train loss 3.6060, val loss 3.6893
# step 2230: train loss 3.6562, val loss 3.6748
# step 2240: train loss 3.6703, val loss 3.7648
# step 2250: train loss 3.6349, val loss 3.7592
# step 2260: train loss 3.6096, val loss 3.7125
# step 2270: train loss 3.5704, val loss 3.6704
# step 2280: train loss 3.6661, val loss 3.6456
# step 2290: train loss 3.6154, val loss 3.7785
# step 2300: train loss 3.5808, val loss 3.7210
# step 2310: train loss 3.5840, val loss 3.6376
# step 2320: train loss 3.5644, val loss 3.7063
# step 2330: train loss 3.5795, val loss 3.6691
# step 2340: train loss 3.6231, val loss 3.6611
# step 2350: train loss 3.6297, val loss 3.7162
# step 2360: train loss 3.5506, val loss 3.6845
# step 2370: train loss 3.6253, val loss 3.5976
# step 2380: train loss 3.5730, val loss 3.6223
# step 2390: train loss 3.6064, val loss 3.6359
# step 2400: train loss 3.5939, val loss 3.7078
# step 2410: train loss 3.5730, val loss 3.6394
# step 2420: train loss 3.5873, val loss 3.6257
# step 2430: train loss 3.5365, val loss 3.5714
# step 2440: train loss 3.5481, val loss 3.7145
# step 2450: train loss 3.5340, val loss 3.6459
# step 2460: train loss 3.5132, val loss 3.5990
# step 2470: train loss 3.5737, val loss 3.5820
# step 2480: train loss 3.4948, val loss 3.5879
# step 2490: train loss 3.5761, val loss 3.5793
# step 2500: train loss 3.5822, val loss 3.6392
# step 2510: train loss 3.5534, val loss 3.6632
# step 2520: train loss 3.4610, val loss 3.6819
# step 2530: train loss 3.5230, val loss 3.5487
# step 2540: train loss 3.5846, val loss 3.5902
# step 2550: train loss 3.4644, val loss 3.6111
# step 2560: train loss 3.4731, val loss 3.5814
# step 2570: train loss 3.4409, val loss 3.5883
# step 2580: train loss 3.4396, val loss 3.6459
# step 2590: train loss 3.3807, val loss 3.5969
# step 2600: train loss 3.4466, val loss 3.5274
# step 2610: train loss 3.4989, val loss 3.5319
# step 2620: train loss 3.5460, val loss 3.6173
# step 2630: train loss 3.4380, val loss 3.5891
# step 2640: train loss 3.4676, val loss 3.5127
# step 2650: train loss 3.4349, val loss 3.5087
# step 2660: train loss 3.5470, val loss 3.5548
# step 2670: train loss 3.4752, val loss 3.5306
# step 2680: train loss 3.4624, val loss 3.4955
# step 2690: train loss 3.4000, val loss 3.5800
# step 2700: train loss 3.4715, val loss 3.5153
# step 2710: train loss 3.4078, val loss 3.5252
# step 2720: train loss 3.4233, val loss 3.5288
# step 2730: train loss 3.4062, val loss 3.4926
# step 2740: train loss 3.4648, val loss 3.4486
# step 2750: train loss 3.4081, val loss 3.5083
# step 2760: train loss 3.4327, val loss 3.5179
# step 2770: train loss 3.4405, val loss 3.5350
# step 2780: train loss 3.4297, val loss 3.4895
# step 2790: train loss 3.3659, val loss 3.5335
# step 2800: train loss 3.3644, val loss 3.3752
# step 2810: train loss 3.4576, val loss 3.5036
# step 2820: train loss 3.4381, val loss 3.4829
# step 2830: train loss 3.3459, val loss 3.4865
# step 2840: train loss 3.4066, val loss 3.5241
# step 2850: train loss 3.3845, val loss 3.5002
# step 2860: train loss 3.3386, val loss 3.3629
# step 2870: train loss 3.3903, val loss 3.4705
# step 2880: train loss 3.4197, val loss 3.4930
# step 2890: train loss 3.2846, val loss 3.4962
# step 2900: train loss 3.3448, val loss 3.5222
# step 2910: train loss 3.3917, val loss 3.4418
# step 2920: train loss 3.4188, val loss 3.4076
# step 2930: train loss 3.3653, val loss 3.3761
# step 2940: train loss 3.3647, val loss 3.3843
# step 2950: train loss 3.3300, val loss 3.4901
# step 2960: train loss 3.3016, val loss 3.4755
# step 2970: train loss 3.3598, val loss 3.4884
# step 2980: train loss 3.3601, val loss 3.3928
# step 2990: train loss 3.4010, val loss 3.4197
# step 3000: train loss 3.3072, val loss 3.3931
# step 3010: train loss 3.3036, val loss 3.4655
# step 3020: train loss 3.3955, val loss 3.4235
# step 3030: train loss 3.3377, val loss 3.4389
# step 3040: train loss 3.3765, val loss 3.3349
# step 3050: train loss 3.3410, val loss 3.3570
# step 3060: train loss 3.3222, val loss 3.3967
# step 3070: train loss 3.3062, val loss 3.5035
# step 3080: train loss 3.3589, val loss 3.3587
# step 3090: train loss 3.3126, val loss 3.3470
# step 3100: train loss 3.2664, val loss 3.4757
# step 3110: train loss 3.2332, val loss 3.3910
# step 3120: train loss 3.2788, val loss 3.4657
# step 3130: train loss 3.2683, val loss 3.4943
# step 3140: train loss 3.2759, val loss 3.4481
# step 3150: train loss 3.3257, val loss 3.4187
# step 3160: train loss 3.2378, val loss 3.3281
# step 3170: train loss 3.2491, val loss 3.4192
# step 3180: train loss 3.2789, val loss 3.3491
# step 3190: train loss 3.2732, val loss 3.2816
# step 3200: train loss 3.2616, val loss 3.3772
# step 3210: train loss 3.2575, val loss 3.3301
# step 3220: train loss 3.3758, val loss 3.4039
# step 3230: train loss 3.2736, val loss 3.3883
# step 3240: train loss 3.2053, val loss 3.4441
# step 3250: train loss 3.2816, val loss 3.3960
# step 3260: train loss 3.2318, val loss 3.3400
# step 3270: train loss 3.2664, val loss 3.4771
# step 3280: train loss 3.2158, val loss 3.3335
# step 3290: train loss 3.2551, val loss 3.4358
# step 3300: train loss 3.3187, val loss 3.3152
# step 3310: train loss 3.2340, val loss 3.3162
# step 3320: train loss 3.2711, val loss 3.2429
# step 3330: train loss 3.2475, val loss 3.3136
# step 3340: train loss 3.2594, val loss 3.2880
# step 3350: train loss 3.2161, val loss 3.1908
# step 3360: train loss 3.1661, val loss 3.3412
# step 3370: train loss 3.2379, val loss 3.3246
# step 3380: train loss 3.1725, val loss 3.3162
# step 3390: train loss 3.1780, val loss 3.2553
# step 3400: train loss 3.2786, val loss 3.3511
# step 3410: train loss 3.1850, val loss 3.2598
# step 3420: train loss 3.2711, val loss 3.3036
# step 3430: train loss 3.2017, val loss 3.3153
# step 3440: train loss 3.2886, val loss 3.2265
# step 3450: train loss 3.3086, val loss 3.3129
# step 3460: train loss 3.1947, val loss 3.2437
# step 3470: train loss 3.1712, val loss 3.3286
# step 3480: train loss 3.2304, val loss 3.2682
# step 3490: train loss 3.2899, val loss 3.3043
# step 3500: train loss 3.1194, val loss 3.3095
# step 3510: train loss 3.2197, val loss 3.2950
# step 3520: train loss 3.1129, val loss 3.2766
# step 3530: train loss 3.1903, val loss 3.2039
# step 3540: train loss 3.1908, val loss 3.3709
# step 3550: train loss 3.1227, val loss 3.2929
# step 3560: train loss 3.1773, val loss 3.2231
# step 3570: train loss 3.2009, val loss 3.2700
# step 3580: train loss 3.0981, val loss 3.1998
# step 3590: train loss 3.1518, val loss 3.2506
# step 3600: train loss 3.1531, val loss 3.2154
# step 3610: train loss 3.1386, val loss 3.2675
# step 3620: train loss 3.1386, val loss 3.3208
# step 3630: train loss 3.2011, val loss 3.2533
# step 3640: train loss 3.2165, val loss 3.2312
# step 3650: train loss 3.1276, val loss 3.2987
# step 3660: train loss 3.2345, val loss 3.2804
# step 3670: train loss 3.1227, val loss 3.1826
# step 3680: train loss 3.1961, val loss 3.1528
# step 3690: train loss 3.1366, val loss 3.2199
# step 3700: train loss 3.1597, val loss 3.1792
# step 3710: train loss 3.2141, val loss 3.1540
# step 3720: train loss 3.1073, val loss 3.2072
# step 3730: train loss 3.1005, val loss 3.1575
# step 3740: train loss 3.1097, val loss 3.1968
# step 3750: train loss 3.1140, val loss 3.1563
# step 3760: train loss 3.0799, val loss 3.1986
# step 3770: train loss 3.1514, val loss 3.1700
# step 3780: train loss 3.2135, val loss 3.1770
# step 3790: train loss 3.1551, val loss 3.2567
# step 3800: train loss 3.1650, val loss 3.1476
# step 3810: train loss 3.0858, val loss 3.1746
# step 3820: train loss 3.1239, val loss 3.1926
# step 3830: train loss 3.0396, val loss 3.1791
# step 3840: train loss 3.0871, val loss 3.2060
# step 3850: train loss 3.1219, val loss 3.2806
# step 3860: train loss 3.0284, val loss 3.1617
# step 3870: train loss 3.1038, val loss 3.2565
# step 3880: train loss 3.0254, val loss 3.1728
# step 3890: train loss 3.0958, val loss 3.2564
# step 3900: train loss 3.1306, val loss 3.1549
# step 3910: train loss 3.0252, val loss 3.1134
# step 3920: train loss 3.0712, val loss 3.1092
# step 3930: train loss 3.0851, val loss 3.0750
# step 3940: train loss 3.0978, val loss 3.1896
# step 3950: train loss 3.1183, val loss 3.2096
# step 3960: train loss 3.0476, val loss 3.2805
# step 3970: train loss 3.1178, val loss 3.2154
# step 3980: train loss 3.1212, val loss 3.1484
# step 3990: train loss 3.0166, val loss 3.0858
# step 4000: train loss 3.0039, val loss 3.1293
# step 4010: train loss 3.0715, val loss 3.1834
# step 4020: train loss 3.0690, val loss 3.0960
# step 4030: train loss 3.0128, val loss 3.0758
# step 4040: train loss 3.0467, val loss 3.1533
# step 4050: train loss 2.9419, val loss 3.1355
# step 4060: train loss 3.0888, val loss 3.2131
# step 4070: train loss 3.0358, val loss 3.0695
# step 4080: train loss 3.0743, val loss 3.1814
# step 4090: train loss 3.0922, val loss 3.1798
# step 4100: train loss 3.0004, val loss 3.1665
# step 4110: train loss 3.0251, val loss 3.1312
# step 4120: train loss 3.0706, val loss 3.1243
# step 4130: train loss 2.9463, val loss 3.1647
# step 4140: train loss 3.0237, val loss 3.1049
# step 4150: train loss 2.9821, val loss 3.0914
# step 4160: train loss 3.0334, val loss 3.0299
# step 4170: train loss 3.0529, val loss 3.0472
# step 4180: train loss 2.9724, val loss 3.0671
# step 4190: train loss 3.0161, val loss 3.0286
# step 4200: train loss 2.9860, val loss 3.0684
# step 4210: train loss 3.0185, val loss 3.0854
# step 4220: train loss 2.9299, val loss 3.0318
# step 4230: train loss 2.9945, val loss 3.0872
# step 4240: train loss 2.9636, val loss 3.0759
# step 4250: train loss 3.1123, val loss 3.0347
# step 4260: train loss 2.9420, val loss 3.1064
# step 4270: train loss 2.9666, val loss 3.1549
# step 4280: train loss 2.9309, val loss 3.0627
# step 4290: train loss 2.9847, val loss 3.1115
# step 4300: train loss 2.9916, val loss 3.1781
# step 4310: train loss 2.9278, val loss 3.0629
# step 4320: train loss 3.0500, val loss 3.0806
# step 4330: train loss 2.9764, val loss 3.0556
# step 4340: train loss 2.9715, val loss 3.0502
# step 4350: train loss 2.9421, val loss 3.1301
# step 4360: train loss 2.9756, val loss 3.1754
# step 4370: train loss 3.0519, val loss 3.0325
# step 4380: train loss 2.9659, val loss 2.9635
# step 4390: train loss 2.9577, val loss 3.1049
# step 4400: train loss 2.9472, val loss 3.1032
# step 4410: train loss 2.9674, val loss 3.1192
# step 4420: train loss 2.9223, val loss 3.0356
# step 4430: train loss 2.9602, val loss 3.1218
# step 4440: train loss 2.9937, val loss 2.9750
# step 4450: train loss 2.9708, val loss 2.9673
# step 4460: train loss 3.0319, val loss 2.9785
# step 4470: train loss 2.9100, val loss 3.0274
# step 4480: train loss 2.9924, val loss 3.0493
# step 4490: train loss 2.9692, val loss 3.1344
# step 4500: train loss 2.8719, val loss 3.0482
# step 4510: train loss 2.9105, val loss 3.1819
# step 4520: train loss 2.9529, val loss 3.0784
# step 4530: train loss 2.9769, val loss 3.0535
# step 4540: train loss 2.9136, val loss 3.0548
# step 4550: train loss 2.9392, val loss 2.9924
# step 4560: train loss 2.9397, val loss 3.0966
# step 4570: train loss 2.9146, val loss 3.0378
# step 4580: train loss 2.9970, val loss 3.1306
# step 4590: train loss 2.8913, val loss 2.9007
# step 4600: train loss 2.8672, val loss 3.0732
# step 4610: train loss 2.8752, val loss 2.9716
# step 4620: train loss 2.9866, val loss 3.0566
# step 4630: train loss 2.8723, val loss 3.0005
# step 4640: train loss 2.9139, val loss 3.0114
# step 4650: train loss 2.9094, val loss 3.0049
# step 4660: train loss 3.0025, val loss 3.0192
# step 4670: train loss 2.9485, val loss 2.9774
# step 4680: train loss 2.8934, val loss 2.9757
# step 4690: train loss 2.9549, val loss 3.0828
# step 4700: train loss 2.9735, val loss 2.9701
# step 4710: train loss 2.9202, val loss 3.0363
# step 4720: train loss 2.8781, val loss 2.9585
# step 4730: train loss 2.8797, val loss 2.9276
# step 4740: train loss 2.8529, val loss 3.0091
# step 4750: train loss 2.8923, val loss 3.0898
# step 4760: train loss 2.9268, val loss 3.0834
# step 4770: train loss 2.8715, val loss 3.0069
# step 4780: train loss 2.8151, val loss 3.0256
# step 4790: train loss 2.8448, val loss 2.9712
# step 4800: train loss 2.9091, val loss 3.0101
# step 4810: train loss 2.9727, val loss 2.9475
# step 4820: train loss 2.9571, val loss 3.0530
# step 4830: train loss 2.8345, val loss 3.0025
# step 4840: train loss 2.9114, val loss 2.9795
# step 4850: train loss 2.9348, val loss 2.9251
# step 4860: train loss 2.7961, val loss 3.0205
# step 4870: train loss 2.8860, val loss 2.9413
# step 4880: train loss 2.9035, val loss 2.9887
# step 4890: train loss 2.8379, val loss 2.8794
# step 4900: train loss 2.9490, val loss 2.9494
# step 4910: train loss 2.8911, val loss 2.9353
# step 4920: train loss 2.8843, val loss 2.9722
# step 4930: train loss 2.8673, val loss 2.9624
# step 4940: train loss 2.8506, val loss 2.9123
# step 4950: train loss 2.7953, val loss 2.9136
# step 4960: train loss 2.9539, val loss 2.9813
# step 4970: train loss 2.8589, val loss 3.0057
# step 4980: train loss 2.8147, val loss 2.9578
# step 4990: train loss 2.8032, val loss 2.9406
# step 5000: train loss 2.8680, val loss 2.9370
# step 5010: train loss 2.9006, val loss 3.0865
# step 5020: train loss 2.7971, val loss 2.8980
# step 5030: train loss 2.8872, val loss 2.9590
# step 5040: train loss 2.8342, val loss 2.9671
# step 5050: train loss 2.8221, val loss 2.9861
# step 5060: train loss 2.8327, val loss 2.8698
# step 5070: train loss 2.8861, val loss 2.9205
# step 5080: train loss 2.8941, val loss 2.9434
# step 5090: train loss 2.8012, val loss 2.9796
# step 5100: train loss 2.8792, val loss 2.9086
# step 5110: train loss 2.8819, val loss 2.9592
# step 5120: train loss 2.9778, val loss 2.9295
# step 5130: train loss 2.8533, val loss 2.8831
# step 5140: train loss 2.8514, val loss 2.9398
# step 5150: train loss 2.9133, val loss 2.8857
# step 5160: train loss 2.8774, val loss 3.0380
# step 5170: train loss 2.8479, val loss 2.9580
# step 5180: train loss 2.9475, val loss 2.9453
# step 5190: train loss 2.9002, val loss 2.9106
# step 5200: train loss 2.9057, val loss 2.9178
# step 5210: train loss 2.7658, val loss 2.8547
# step 5220: train loss 2.8012, val loss 2.9825
# step 5230: train loss 2.8165, val loss 2.9248
# step 5240: train loss 2.8920, val loss 2.8609
# step 5250: train loss 2.7711, val loss 2.9754
# step 5260: train loss 2.8896, val loss 2.9269
# step 5270: train loss 2.8083, val loss 2.9570
# step 5280: train loss 2.7609, val loss 2.8671
# step 5290: train loss 2.8282, val loss 2.9444
# step 5300: train loss 2.8023, val loss 2.8347
# step 5310: train loss 2.8139, val loss 2.9293
# step 5320: train loss 2.7913, val loss 2.9216
# step 5330: train loss 2.8004, val loss 2.8439
# step 5340: train loss 2.8302, val loss 2.9504
# step 5350: train loss 2.8612, val loss 2.9251
# step 5360: train loss 2.8318, val loss 2.8924
# step 5370: train loss 2.8054, val loss 2.9179
# step 5380: train loss 2.8318, val loss 2.8925
# step 5390: train loss 2.7328, val loss 2.9164
# step 5400: train loss 2.8066, val loss 2.8882
# step 5410: train loss 2.8281, val loss 2.7938
# step 5420: train loss 2.7293, val loss 2.8476
# step 5430: train loss 2.7619, val loss 2.8504
# step 5440: train loss 2.7753, val loss 2.9045
# step 5450: train loss 2.8580, val loss 2.8873
# step 5460: train loss 2.7463, val loss 2.9971
# step 5470: train loss 2.7384, val loss 2.8144
# step 5480: train loss 2.7888, val loss 2.9325
# step 5490: train loss 2.8174, val loss 2.9878
# step 5500: train loss 2.8059, val loss 2.8439
# step 5510: train loss 2.7072, val loss 2.8432
# step 5520: train loss 2.7730, val loss 2.8822
# step 5530: train loss 2.7943, val loss 2.8651
# step 5540: train loss 2.7975, val loss 2.8532
# step 5550: train loss 2.7884, val loss 2.8807
# step 5560: train loss 2.8441, val loss 2.9609
# step 5570: train loss 2.7879, val loss 2.8807
# step 5580: train loss 2.8072, val loss 2.8551
# step 5590: train loss 2.7823, val loss 2.8941
# step 5600: train loss 2.7784, val loss 2.8686
# step 5610: train loss 2.7709, val loss 2.9246
# step 5620: train loss 2.9075, val loss 2.8357
# step 5630: train loss 2.7419, val loss 2.9558
# step 5640: train loss 2.8386, val loss 2.8487
# step 5650: train loss 2.6988, val loss 2.8369
# step 5660: train loss 2.7105, val loss 2.8790
# step 5670: train loss 2.7570, val loss 2.8590
# step 5680: train loss 2.8610, val loss 2.8711
# step 5690: train loss 2.7405, val loss 2.8881
# step 5700: train loss 2.7374, val loss 2.8179
# step 5710: train loss 2.6423, val loss 2.9424
# step 5720: train loss 2.7401, val loss 2.9017
# step 5730: train loss 2.7488, val loss 2.7969
# step 5740: train loss 2.7240, val loss 2.9218
# step 5750: train loss 2.7194, val loss 2.7216
# step 5760: train loss 2.7114, val loss 2.7984
# step 5770: train loss 2.8085, val loss 2.8680
# step 5780: train loss 2.7721, val loss 2.7900
# step 5790: train loss 2.7361, val loss 2.8414
# step 5800: train loss 2.7707, val loss 2.7959
# step 5810: train loss 2.7632, val loss 2.8697
# step 5820: train loss 2.7208, val loss 2.8987
# step 5830: train loss 2.7936, val loss 2.8528
# step 5840: train loss 2.7824, val loss 2.7893
# step 5850: train loss 2.7505, val loss 2.7660
# step 5860: train loss 2.7103, val loss 2.9486
# step 5870: train loss 2.8120, val loss 2.8225
# step 5880: train loss 2.7486, val loss 2.8470
# step 5890: train loss 2.7260, val loss 2.7673
# step 5900: train loss 2.7527, val loss 2.8953
# step 5910: train loss 2.7244, val loss 2.9007
# step 5920: train loss 2.6819, val loss 2.7254
# step 5930: train loss 2.7086, val loss 2.9410
# step 5940: train loss 2.7671, val loss 2.7502
# step 5950: train loss 2.6900, val loss 2.7969
# step 5960: train loss 2.7015, val loss 2.7720
# step 5970: train loss 2.7119, val loss 2.8402
# step 5980: train loss 2.7275, val loss 2.8038
# step 5990: train loss 2.7021, val loss 2.7643
# step 6000: train loss 2.7800, val loss 2.7526
# step 6010: train loss 2.7211, val loss 2.8376
# step 6020: train loss 2.6615, val loss 2.8449
# step 6030: train loss 2.7360, val loss 2.8014
# step 6040: train loss 2.7067, val loss 2.6809
# step 6050: train loss 2.7508, val loss 2.8153
# step 6060: train loss 2.7492, val loss 2.7965
# step 6070: train loss 2.7919, val loss 2.8224
# step 6080: train loss 2.7244, val loss 2.7050
# step 6090: train loss 2.7276, val loss 2.6995
# step 6100: train loss 2.7607, val loss 2.6908
# step 6110: train loss 2.7501, val loss 2.8579
# step 6120: train loss 2.7239, val loss 2.7683
# step 6130: train loss 2.7335, val loss 2.9129
# step 6140: train loss 2.7163, val loss 2.8311
# step 6150: train loss 2.6687, val loss 2.9471
# step 6160: train loss 2.7430, val loss 2.8171
# step 6170: train loss 2.6679, val loss 2.9285
# step 6180: train loss 2.7303, val loss 2.7412
# step 6190: train loss 2.6819, val loss 2.7833
# step 6200: train loss 2.7082, val loss 2.7552
# step 6210: train loss 2.7324, val loss 2.8076
# step 6220: train loss 2.7344, val loss 2.8248
# step 6230: train loss 2.6858, val loss 2.8762
# step 6240: train loss 2.6671, val loss 2.7728
# step 6250: train loss 2.7188, val loss 2.7637
# step 6260: train loss 2.6581, val loss 2.6771
# step 6270: train loss 2.6918, val loss 2.8540
# step 6280: train loss 2.6892, val loss 2.7789
# step 6290: train loss 2.6702, val loss 2.7781
# step 6300: train loss 2.6589, val loss 2.8517
# step 6310: train loss 2.7419, val loss 2.7532
# step 6320: train loss 2.7149, val loss 2.7868
# step 6330: train loss 2.7424, val loss 2.8850
# step 6340: train loss 2.7145, val loss 2.8354
# step 6350: train loss 2.6384, val loss 2.7861
# step 6360: train loss 2.7052, val loss 2.7937
# step 6370: train loss 2.6794, val loss 2.8511
# step 6380: train loss 2.7829, val loss 2.7314
# step 6390: train loss 2.6600, val loss 2.8661
# step 6400: train loss 2.6531, val loss 2.6849
# step 6410: train loss 2.6953, val loss 2.8673
# step 6420: train loss 2.6784, val loss 2.7958
# step 6430: train loss 2.6626, val loss 2.8838
# step 6440: train loss 2.5958, val loss 2.7589
# step 6450: train loss 2.7103, val loss 2.7780
# step 6460: train loss 2.6623, val loss 2.7881
# step 6470: train loss 2.6238, val loss 2.8343
# step 6480: train loss 2.6406, val loss 2.8147
# step 6490: train loss 2.6744, val loss 2.7578
# step 6500: train loss 2.7084, val loss 2.7830
# step 6510: train loss 2.6357, val loss 2.7364
# step 6520: train loss 2.7237, val loss 2.7280
# step 6530: train loss 2.6276, val loss 2.7491
# step 6540: train loss 2.7536, val loss 2.7149
# step 6550: train loss 2.6692, val loss 2.7442
# step 6560: train loss 2.6138, val loss 2.7253
# step 6570: train loss 2.6698, val loss 2.7932
# step 6580: train loss 2.6074, val loss 2.8811
# step 6590: train loss 2.7229, val loss 2.6984
# step 6600: train loss 2.6474, val loss 2.7540
# step 6610: train loss 2.7029, val loss 2.7414
# step 6620: train loss 2.6088, val loss 2.6514
# step 6630: train loss 2.6473, val loss 2.7523
# step 6640: train loss 2.6855, val loss 2.8812
# step 6650: train loss 2.6678, val loss 2.7419
# step 6660: train loss 2.6560, val loss 2.7925
# step 6670: train loss 2.6760, val loss 2.8152
# step 6680: train loss 2.6469, val loss 2.7115
# step 6690: train loss 2.5541, val loss 2.7513
# step 6700: train loss 2.6009, val loss 2.7434
# step 6710: train loss 2.6284, val loss 2.7433
# step 6720: train loss 2.6869, val loss 2.7518
# step 6730: train loss 2.6687, val loss 2.6266
# step 6740: train loss 2.7130, val loss 2.7071
# step 6750: train loss 2.7030, val loss 2.7159
# step 6760: train loss 2.6783, val loss 2.7424
# step 6770: train loss 2.6178, val loss 2.8007
# step 6780: train loss 2.6494, val loss 2.7843
# step 6790: train loss 2.6494, val loss 2.7857
# step 6800: train loss 2.6589, val loss 2.6635
# step 6810: train loss 2.6316, val loss 2.7750
# step 6820: train loss 2.7060, val loss 2.8166
# step 6830: train loss 2.6742, val loss 2.7552
# step 6840: train loss 2.7304, val loss 2.6876
# step 6850: train loss 2.6814, val loss 2.8301
# step 6860: train loss 2.6506, val loss 2.9186
# step 6870: train loss 2.6245, val loss 2.7286
# step 6880: train loss 2.7636, val loss 2.7600
# step 6890: train loss 2.6225, val loss 2.7816
# step 6900: train loss 2.6436, val loss 2.6507
# step 6910: train loss 2.5913, val loss 2.8186
# step 6920: train loss 2.6161, val loss 2.7485
# step 6930: train loss 2.7006, val loss 2.7317
# step 6940: train loss 2.6795, val loss 2.6856
# step 6950: train loss 2.5999, val loss 2.7368
# step 6960: train loss 2.5753, val loss 2.6701
# step 6970: train loss 2.6166, val loss 2.7193
# step 6980: train loss 2.5903, val loss 2.7953
# step 6990: train loss 2.6360, val loss 2.7153
# step 7000: train loss 2.6530, val loss 2.7394
# step 7010: train loss 2.6130, val loss 2.7643
# step 7020: train loss 2.5782, val loss 2.7603
# step 7030: train loss 2.5861, val loss 2.7062
# step 7040: train loss 2.6315, val loss 2.6916
# step 7050: train loss 2.5770, val loss 2.7099
# step 7060: train loss 2.6554, val loss 2.7186
# step 7070: train loss 2.5683, val loss 2.6884
# step 7080: train loss 2.5653, val loss 2.7124
# step 7090: train loss 2.6035, val loss 2.6662
# step 7100: train loss 2.7385, val loss 2.7289
# step 7110: train loss 2.6441, val loss 2.8986
# step 7120: train loss 2.6266, val loss 2.7959
# step 7130: train loss 2.6641, val loss 2.9071
# step 7140: train loss 2.6086, val loss 2.6766
# step 7150: train loss 2.6203, val loss 2.7585
# step 7160: train loss 2.6470, val loss 2.6562
# step 7170: train loss 2.6289, val loss 2.6650
# step 7180: train loss 2.6396, val loss 2.6200
# step 7190: train loss 2.6453, val loss 2.7462
# step 7200: train loss 2.7082, val loss 2.6692
# step 7210: train loss 2.6457, val loss 2.7459
# step 7220: train loss 2.5643, val loss 2.7115
# step 7230: train loss 2.5735, val loss 2.6664
# step 7240: train loss 2.6452, val loss 2.7733
# step 7250: train loss 2.6356, val loss 2.6695
# step 7260: train loss 2.6346, val loss 2.6447
# step 7270: train loss 2.5623, val loss 2.7924
# step 7280: train loss 2.6129, val loss 2.8079
# step 7290: train loss 2.6378, val loss 2.8199
# step 7300: train loss 2.5805, val loss 2.7133
# step 7310: train loss 2.5940, val loss 2.6519
# step 7320: train loss 2.6591, val loss 2.6318
# step 7330: train loss 2.6616, val loss 2.7159
# step 7340: train loss 2.5966, val loss 2.7610
# step 7350: train loss 2.5917, val loss 2.6228
# step 7360: train loss 2.6414, val loss 2.7640
# step 7370: train loss 2.6674, val loss 2.6068
# step 7380: train loss 2.5494, val loss 2.6584
# step 7390: train loss 2.6314, val loss 2.6855
# step 7400: train loss 2.6625, val loss 2.7332
# step 7410: train loss 2.5015, val loss 2.6027
# step 7420: train loss 2.5456, val loss 2.6992
# step 7430: train loss 2.6130, val loss 2.7488
# step 7440: train loss 2.7089, val loss 2.7411
# step 7450: train loss 2.6133, val loss 2.7027
# step 7460: train loss 2.6261, val loss 2.6446
# step 7470: train loss 2.6327, val loss 2.5489
# step 7480: train loss 2.5604, val loss 2.7304
# step 7490: train loss 2.6147, val loss 2.7329
# step 7500: train loss 2.6925, val loss 2.6928
# step 7510: train loss 2.5643, val loss 2.6856
# step 7520: train loss 2.5402, val loss 2.6958
# step 7530: train loss 2.5325, val loss 2.7057
# step 7540: train loss 2.6804, val loss 2.6975
# step 7550: train loss 2.6213, val loss 2.7433
# step 7560: train loss 2.6111, val loss 2.6930
# step 7570: train loss 2.5682, val loss 2.8087
# step 7580: train loss 2.6116, val loss 2.7597
# step 7590: train loss 2.6920, val loss 2.6951
# step 7600: train loss 2.6481, val loss 2.7001
# step 7610: train loss 2.6291, val loss 2.6605
# step 7620: train loss 2.6680, val loss 2.7374
# step 7630: train loss 2.6443, val loss 2.6569
# step 7640: train loss 2.6402, val loss 2.7019
# step 7650: train loss 2.5919, val loss 2.7065
# step 7660: train loss 2.6695, val loss 2.7142
# step 7670: train loss 2.5652, val loss 2.6769
# step 7680: train loss 2.5347, val loss 2.6793
# step 7690: train loss 2.6083, val loss 2.7112
# step 7700: train loss 2.5652, val loss 2.7051
# step 7710: train loss 2.6322, val loss 2.7486
# step 7720: train loss 2.5571, val loss 2.6788
# step 7730: train loss 2.5692, val loss 2.6472
# step 7740: train loss 2.4590, val loss 2.6082
# step 7750: train loss 2.6440, val loss 2.6416
# step 7760: train loss 2.6076, val loss 2.6996
# step 7770: train loss 2.6309, val loss 2.6071
# step 7780: train loss 2.5008, val loss 2.7296
# step 7790: train loss 2.5413, val loss 2.6136
# step 7800: train loss 2.6266, val loss 2.6800
# step 7810: train loss 2.5562, val loss 2.7459
# step 7820: train loss 2.6009, val loss 2.5814
# step 7830: train loss 2.5583, val loss 2.6259
# step 7840: train loss 2.5768, val loss 2.5969
# step 7850: train loss 2.6567, val loss 2.6600
# step 7860: train loss 2.5230, val loss 2.6263
# step 7870: train loss 2.5405, val loss 2.6852
# step 7880: train loss 2.5748, val loss 2.6806
# step 7890: train loss 2.5622, val loss 2.6079
# step 7900: train loss 2.5718, val loss 2.6607
# step 7910: train loss 2.6270, val loss 2.6331
# step 7920: train loss 2.5387, val loss 2.5911
# step 7930: train loss 2.5365, val loss 2.6397
# step 7940: train loss 2.6054, val loss 2.6273
# step 7950: train loss 2.5426, val loss 2.6376
# step 7960: train loss 2.5810, val loss 2.6017
# step 7970: train loss 2.5485, val loss 2.6987
# step 7980: train loss 2.5260, val loss 2.6152
# step 7990: train loss 2.5797, val loss 2.6726
# step 8000: train loss 2.5556, val loss 2.6064
# step 8010: train loss 2.5187, val loss 2.8171
# step 8020: train loss 2.5103, val loss 2.7193
# step 8030: train loss 2.5973, val loss 2.7121
# step 8040: train loss 2.6077, val loss 2.6290
# step 8050: train loss 2.5340, val loss 2.7011
# step 8060: train loss 2.6294, val loss 2.6924
# step 8070: train loss 2.5593, val loss 2.6599
# step 8080: train loss 2.5011, val loss 2.7498
# step 8090: train loss 2.6373, val loss 2.6787
# step 8100: train loss 2.5730, val loss 2.6106
# step 8110: train loss 2.5455, val loss 2.6905
# step 8120: train loss 2.4989, val loss 2.6238
# step 8130: train loss 2.5529, val loss 2.6525
# step 8140: train loss 2.5158, val loss 2.6409
# step 8150: train loss 2.5322, val loss 2.7263
# step 8160: train loss 2.5580, val loss 2.6397
# step 8170: train loss 2.5964, val loss 2.6117
# step 8180: train loss 2.5499, val loss 2.6190
# step 8190: train loss 2.5135, val loss 2.6970
# step 8200: train loss 2.6199, val loss 2.6490
# step 8210: train loss 2.5388, val loss 2.6437
# step 8220: train loss 2.4692, val loss 2.6048
# step 8230: train loss 2.5050, val loss 2.8735
# step 8240: train loss 2.5876, val loss 2.7008
# step 8250: train loss 2.5610, val loss 2.7434
# step 8260: train loss 2.6158, val loss 2.5678
# step 8270: train loss 2.5596, val loss 2.5567
# step 8280: train loss 2.6086, val loss 2.5815
# step 8290: train loss 2.5456, val loss 2.8179
# step 8300: train loss 2.5310, val loss 2.5953
# step 8310: train loss 2.6122, val loss 2.6172
# step 8320: train loss 2.6125, val loss 2.6232
# step 8330: train loss 2.5476, val loss 2.5847
# step 8340: train loss 2.6088, val loss 2.6149
# step 8350: train loss 2.5004, val loss 2.6593
# step 8360: train loss 2.5555, val loss 2.5225
# step 8370: train loss 2.5796, val loss 2.7108
# step 8380: train loss 2.5539, val loss 2.6516
# step 8390: train loss 2.5548, val loss 2.6171
# step 8400: train loss 2.5444, val loss 2.6948
# step 8410: train loss 2.5377, val loss 2.5586
# step 8420: train loss 2.5821, val loss 2.6640
# step 8430: train loss 2.6244, val loss 2.7532
# step 8440: train loss 2.5258, val loss 2.6861
# step 8450: train loss 2.4537, val loss 2.6208
# step 8460: train loss 2.5973, val loss 2.6816
# step 8470: train loss 2.6083, val loss 2.6868
# step 8480: train loss 2.5572, val loss 2.6049
# step 8490: train loss 2.5291, val loss 2.5744
# step 8500: train loss 2.5581, val loss 2.5753
# step 8510: train loss 2.5249, val loss 2.6410
# step 8520: train loss 2.5382, val loss 2.5449
# step 8530: train loss 2.5458, val loss 2.7081
# step 8540: train loss 2.5032, val loss 2.6000
# step 8550: train loss 2.5087, val loss 2.6580
# step 8560: train loss 2.4890, val loss 2.5969
# step 8570: train loss 2.5572, val loss 2.6038
# step 8580: train loss 2.5532, val loss 2.6506
# step 8590: train loss 2.5557, val loss 2.6054
# step 8600: train loss 2.5505, val loss 2.5946
# step 8610: train loss 2.5341, val loss 2.5672
# step 8620: train loss 2.5031, val loss 2.6662
# step 8630: train loss 2.5606, val loss 2.6527
# step 8640: train loss 2.5016, val loss 2.6519
# step 8650: train loss 2.5820, val loss 2.6767
# step 8660: train loss 2.6136, val loss 2.6902
# step 8670: train loss 2.5449, val loss 2.5748
# step 8680: train loss 2.5699, val loss 2.7015
# step 8690: train loss 2.4893, val loss 2.7201
# step 8700: train loss 2.5608, val loss 2.5707
# step 8710: train loss 2.5005, val loss 2.7194
# step 8720: train loss 2.5686, val loss 2.6231
# step 8730: train loss 2.5733, val loss 2.7836
# step 8740: train loss 2.5405, val loss 2.5967
# step 8750: train loss 2.5362, val loss 2.5614
# step 8760: train loss 2.4569, val loss 2.5526
# step 8770: train loss 2.5432, val loss 2.5558
# step 8780: train loss 2.4413, val loss 2.5412
# step 8790: train loss 2.4810, val loss 2.5609
# step 8800: train loss 2.5609, val loss 2.7239
# step 8810: train loss 2.5014, val loss 2.6518
# step 8820: train loss 2.4831, val loss 2.5805
# step 8830: train loss 2.5636, val loss 2.6224
# step 8840: train loss 2.4711, val loss 2.6409
# step 8850: train loss 2.5686, val loss 2.6553
# step 8860: train loss 2.5294, val loss 2.5784
# step 8870: train loss 2.5633, val loss 2.5224
# step 8880: train loss 2.6168, val loss 2.5827
# step 8890: train loss 2.4822, val loss 2.6084
# step 8900: train loss 2.5285, val loss 2.6359
# step 8910: train loss 2.5052, val loss 2.6834
# step 8920: train loss 2.5017, val loss 2.5005
# step 8930: train loss 2.4850, val loss 2.6501
# step 8940: train loss 2.5116, val loss 2.7022
# step 8950: train loss 2.4932, val loss 2.6668
# step 8960: train loss 2.4616, val loss 2.6303
# step 8970: train loss 2.5038, val loss 2.6331
# step 8980: train loss 2.4638, val loss 2.6275
# step 8990: train loss 2.6060, val loss 2.5878
# step 9000: train loss 2.6240, val loss 2.7090
# step 9010: train loss 2.4870, val loss 2.6518
# step 9020: train loss 2.4654, val loss 2.6663
# step 9030: train loss 2.5646, val loss 2.5747
# step 9040: train loss 2.5896, val loss 2.6878
# step 9050: train loss 2.5454, val loss 2.6933
# step 9060: train loss 2.4618, val loss 2.5835
# step 9070: train loss 2.5503, val loss 2.5583
# step 9080: train loss 2.5609, val loss 2.6186
# step 9090: train loss 2.5152, val loss 2.6261
# step 9100: train loss 2.5185, val loss 2.5886
# step 9110: train loss 2.4955, val loss 2.5245
# step 9120: train loss 2.5374, val loss 2.6771
# step 9130: train loss 2.5215, val loss 2.5825
# step 9140: train loss 2.4821, val loss 2.6106
# step 9150: train loss 2.5313, val loss 2.5229
# step 9160: train loss 2.5847, val loss 2.5640
# step 9170: train loss 2.5213, val loss 2.5828
# step 9180: train loss 2.5317, val loss 2.5504
# step 9190: train loss 2.6037, val loss 2.5607
# step 9200: train loss 2.4546, val loss 2.6335
# step 9210: train loss 2.5660, val loss 2.5917
# step 9220: train loss 2.5145, val loss 2.5874
# step 9230: train loss 2.4673, val loss 2.5685
# step 9240: train loss 2.5381, val loss 2.6657
# step 9250: train loss 2.4950, val loss 2.6071
# step 9260: train loss 2.5254, val loss 2.6302
# step 9270: train loss 2.5472, val loss 2.4945
# step 9280: train loss 2.4375, val loss 2.5058
# step 9290: train loss 2.4724, val loss 2.5787
# step 9300: train loss 2.5752, val loss 2.6249
# step 9310: train loss 2.5582, val loss 2.6168
# step 9320: train loss 2.5248, val loss 2.5577
# step 9330: train loss 2.4440, val loss 2.5850
# step 9340: train loss 2.5240, val loss 2.5067
# step 9350: train loss 2.5325, val loss 2.5538
# step 9360: train loss 2.5350, val loss 2.6605
# step 9370: train loss 2.4518, val loss 2.5557
# step 9380: train loss 2.5222, val loss 2.6737
# step 9390: train loss 2.5139, val loss 2.5800
# step 9400: train loss 2.5008, val loss 2.6451
# step 9410: train loss 2.5123, val loss 2.6586
# step 9420: train loss 2.5292, val loss 2.6142
# step 9430: train loss 2.6028, val loss 2.5845
# step 9440: train loss 2.5138, val loss 2.5871
# step 9450: train loss 2.4915, val loss 2.5420
# step 9460: train loss 2.5650, val loss 2.5594
# step 9470: train loss 2.4612, val loss 2.6401
# step 9480: train loss 2.6130, val loss 2.5633
# step 9490: train loss 2.4987, val loss 2.5629
# step 9500: train loss 2.4879, val loss 2.5245
# step 9510: train loss 2.5351, val loss 2.6055
# step 9520: train loss 2.5128, val loss 2.6114
# step 9530: train loss 2.5134, val loss 2.6039
# step 9540: train loss 2.5130, val loss 2.5807
# step 9550: train loss 2.5094, val loss 2.6542
# step 9560: train loss 2.5382, val loss 2.6657
# step 9570: train loss 2.5182, val loss 2.5526
# step 9580: train loss 2.5172, val loss 2.5767
# step 9590: train loss 2.4362, val loss 2.5903
# step 9600: train loss 2.5374, val loss 2.5456
# step 9610: train loss 2.5404, val loss 2.5279
# step 9620: train loss 2.4553, val loss 2.5018
# step 9630: train loss 2.5145, val loss 2.5939
# step 9640: train loss 2.5334, val loss 2.6816
# step 9650: train loss 2.6427, val loss 2.5572
# step 9660: train loss 2.5016, val loss 2.6245
# step 9670: train loss 2.5690, val loss 2.5993
# step 9680: train loss 2.5226, val loss 2.6087
# step 9690: train loss 2.5562, val loss 2.6970
# step 9700: train loss 2.5647, val loss 2.6583
# step 9710: train loss 2.5606, val loss 2.5519
# step 9720: train loss 2.5452, val loss 2.6388
# step 9730: train loss 2.4695, val loss 2.5313
# step 9740: train loss 2.4810, val loss 2.5922
# step 9750: train loss 2.4881, val loss 2.6542
# step 9760: train loss 2.5734, val loss 2.6645
# step 9770: train loss 2.5646, val loss 2.6446
# step 9780: train loss 2.5377, val loss 2.5186
# step 9790: train loss 2.5673, val loss 2.5592
# step 9800: train loss 2.4589, val loss 2.5338
# step 9810: train loss 2.4637, val loss 2.5364
# step 9820: train loss 2.5328, val loss 2.5243
# step 9830: train loss 2.5433, val loss 2.4781
# step 9840: train loss 2.4950, val loss 2.5032
# step 9850: train loss 2.5142, val loss 2.6556
# step 9860: train loss 2.4405, val loss 2.6344
# step 9870: train loss 2.5105, val loss 2.4854
# step 9880: train loss 2.5276, val loss 2.7037
# step 9890: train loss 2.5298, val loss 2.5692
# step 9900: train loss 2.4801, val loss 2.5990
# step 9910: train loss 2.5310, val loss 2.6914
# step 9920: train loss 2.4138, val loss 2.5590
# step 9930: train loss 2.5502, val loss 2.5348
# step 9940: train loss 2.5090, val loss 2.6228
# step 9950: train loss 2.5796, val loss 2.6018
# step 9960: train loss 2.4954, val loss 2.4903
# step 9970: train loss 2.5303, val loss 2.7039
# step 9980: train loss 2.5124, val loss 2.5571
# step 9990: train loss 2.4848, val loss 2.5856

# %% [markdown]
# Once the network has been trained for 100 iterations, we can generate a sequence of characters.
#
# #### Questions:
# - What is the effect of training?
# - Increase the number of iterations to 1,000 and then to 10,000. Note the obtained loss and the generated sentence. What do you observe?

# %%
idx = torch.ones((1,1), dtype=torch.long, device=device) * 3
print (decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
# Barcrs de fle stux st rlontêts
# Qus,
#
# UW0lestal
# [c'itie.mêe Su! vabîme!6EXçlais minenthem'élileseunte

# %% [markdown]
# Generated sentence after 1,000 iterations :
# ÂHs!êïÊdëD.Æ6gÂucSê:êe71CÊÈêù9çz'Ô1CuOYd8û!ÎéàïyûSP:É«ÂC9Yo'ÔÔSDI«Îx d1je pNNe; wd,:7)k'tam4DHCè?iW6
#
# Generated sentence after 10,000 iterations : Barcrs de fle stux st rlontêts Qus, UW0lestal [c'itie.mêe Su! vabîme!6EXçlais minenthem'élileseunte

# %% [markdown]
# ## Single Head Attention
#
# We will now implement the basic attention mechanism. For each pair of words in the sequence, this mechanism combines:
# - **Q** (*query*): the information being searched for,
# - **K** (*key*): the information retrieved,
# - **V** (*value*): a result vector calculated from the attention mechanism.
#
# ![single head attention](images/single_head_attention.png)
#
# ### Masking
#
# However, since we are using the model to generate sequences, we must not use characters that come after the current character—these are precisely the characters we aim to predict during training. *The future should not be used to predict the future.*
#
# To enforce this constraint, we integrate a **masking matrix** into the process. This matrix ensures that:
# - For the first character in the sequence, only that character is available for prediction (no context).
# - For the second character, only the first and second characters can be used.
# - For the third character, only the first three characters are accessible, and so on.
#
# This results in a **lower triangular matrix**, where each row is normalized (rows sum to 1).

# %%
T = 8

# first version of the contraints with matrix multiplication
# create a lower triangular matrix
weights0 = torch.tril(torch.ones(T,T))
# normalize each row
weights0 = weights0 / weights0.sum(1, keepdim=True) # so that the sum of each row equals 1
print (weights0)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# The [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.functional.softmax.html) function provides another way to achieve normalization.
#
# #### Question:
# - Verify that applying `softmax` results in the same lower triangular matrix.

# %%
tril = torch.tril(torch.ones(T,T))
weights = torch.tril(torch.ones(T,T))
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = nn.functional.softmax(weights, dim=-1)
print (weights)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# ### Implementation
#
# We can now implement the attention layer based on the following formula:
#
# ![attention_formula](images/attention_formula.png)
#
# This involves computing the **queries (Q)**, **keys (K)**, and **values (V)**, applying the **masking mechanism**, and using the **softmax function** to normalize the attention scores before computing the weighted sum of values.

# %% [markdown]
# #### Questions:
#
# - Create the **key**, **query**, and **value** layers as linear layers of dimension `C × head_size`.
# - Apply these layers to `x`.
# - Compute the attention weights:
#   ```python
#   weights = query @ key.transpose(-2, -1)
#   ```
#   (Transpose the second and third dimensions of `key` to enable matrix multiplication).
# - Apply the **normalization factor** (typically, divide by `sqrt(head_size)`).
# - Apply the **triangular mask** and the **softmax** function to `weights`.
# - Apply the **value** layer to `x`.
# - Compute the final output:
#   ```python
#   out = weights @ value(x)
#   ```

# %%
import math

head_size = 16
B, T, C = 4, 8, 32
x = torch.randn(B, T, C)

# defining the Key, Query, and Value linear layers
key   = nn.Linear(C, head_size, bias=False)
query = nn.Linear(C, head_size, bias=False)
value = nn.Linear(C, head_size, bias=False)
k = key(x)    # (B, T, head_size)
q = query(x)  # (B, T, head_size)
v = value(x)  # (B, T, head_size)

# (B, T, head_size) @ (B, head_size, T) --> (B, T, T)
weights = q @ k.transpose(-2, -1) / math.sqrt(head_size)

tril = torch.tril(torch.ones(T, T))
weights = weights.masked_fill(tril == 0, float('-inf'))

# softmax over last dimension (attention distribution)
weights = nn.functional.softmax(weights, dim=-1)

# Multiply attention weights with value vectors
out = weights @ v  # (B, T, head_size)

print("attention weights:\n", weights[0])
print("\nOutput:\n", out[0])
# Out:
# Attention Weights:
#  tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5114, 0.4886, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2459, 0.3676, 0.3865, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3200, 0.1583, 0.2664, 0.2553, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.1423, 0.1994, 0.1991, 0.2143, 0.2449, 0.0000, 0.0000, 0.0000],
#         [0.1296, 0.0873, 0.2110, 0.1498, 0.1549, 0.2673, 0.0000, 0.0000],
#         [0.2295, 0.1005, 0.1731, 0.1065, 0.1661, 0.0717, 0.1525, 0.0000],
#         [0.1673, 0.1676, 0.1529, 0.1008, 0.1722, 0.0753, 0.0997, 0.0643]],
#        grad_fn=<SelectBackward0>)
#
# Output:
#  tensor([[-3.8296e-01,  7.7567e-01,  3.8733e-01,  4.9645e-01, -7.3230e-01,
#          -4.4816e-01,  7.3338e-01, -9.2928e-02,  2.5934e-01, -4.0282e-01,
#           3.1979e-01,  2.3157e-01, -3.7017e-01,  3.0167e-02,  2.5562e-01,
#           1.9657e-01],
#         [-6.1757e-01,  1.6477e-01, -2.4205e-01,  5.4026e-01, -1.2858e-01,
#           4.8494e-02,  5.3960e-01, -4.4246e-01,  4.1677e-01,  3.7793e-01,
#          -5.8759e-02, -5.6471e-02,  2.7038e-01, -7.5252e-01, -6.6058e-02,
#           6.4452e-02],
#         [-4.5599e-01, -2.1809e-01, -2.5328e-01,  6.2973e-01,  3.0250e-02,
#           2.3684e-01,  6.7364e-01, -3.6567e-01,  3.5974e-01,  6.0877e-01,
#           8.3430e-02,  1.2191e-01, -3.4438e-01, -3.3285e-01, -4.8372e-01,
#           3.5093e-04],
#         [-3.6806e-01,  4.3386e-02, -2.0128e-01,  6.9298e-01, -2.3832e-01,
#           2.0498e-01,  4.8186e-01, -6.6469e-02,  3.2881e-01,  3.3595e-01,
#           9.8089e-02,  2.8050e-02, -4.8656e-01, -5.0757e-02, -3.0559e-01,
#           4.8281e-02],
#         [-2.8700e-01, -8.2733e-02, -3.6451e-01,  5.8301e-01,  5.9959e-02,
#           7.3309e-02,  3.1001e-01,  1.3179e-02,  3.4653e-01,  5.2878e-01,
#           5.3274e-02,  3.0345e-02, -2.1954e-01, -2.3182e-01, -5.6306e-01,
#          -1.7019e-01],
#         [-2.5369e-01, -7.3358e-02, -1.5515e-01,  6.6236e-01,  1.4563e-01,
#          -8.9766e-02, -4.3045e-02, -2.1112e-01,  2.8319e-01,  1.3686e-01,
#           2.6223e-01,  1.0682e-01, -4.7517e-01,  2.1617e-01, -4.3557e-01,
#          -5.6703e-03],
#         [-2.4948e-01,  1.1393e-01, -1.0669e-01,  4.8476e-01, -6.6205e-02,
#          -7.9591e-02,  1.5012e-01, -3.5932e-02,  1.3256e-01,  2.9676e-01,
#           5.8343e-02,  1.3808e-01, -2.3737e-01, -1.3009e-01, -3.4389e-01,
#          -6.7439e-02],
#         [-2.1599e-01,  2.9583e-02, -1.9047e-01,  4.4813e-01, -3.2220e-02,
#          -6.1723e-02,  2.9788e-02, -7.2270e-02,  1.9905e-01,  3.6604e-01,
#           5.3494e-02,  1.4006e-01, -1.0731e-01, -2.0773e-01, -3.0499e-01,
#          -9.6185e-03]], grad_fn=<SelectBackward0>)

# %% [markdown]
# ### Questions:
#
# - Copy your code into `gpt_single_head.py`:
#   - Define the **key**, **query**, and **value** layers in the **constructor** of the `Head` class.
#   - Implement the **computations** in the `forward` function.
# - Train the model.
# - What are the **training** and **validation** losses?
# - Does the generated text appear **better** compared to the previous model?

# %% [markdown]
# train loss 2.3324, val loss 2.4422

# %% [markdown]
# ## Multi-Head Attention
#
# Multi-head attention is simply the parallel computation of multiple **single-head attention** mechanisms. Each **single-head attention** output is concatenated to form the output of the **multi-head attention** module. In the original paper's illustration, the number of heads in the **multi-head attention** is denoted as `h`.
#
# To allow for **weighted combinations** of each single-head attention output, a **linear transformation layer** is added after concatenation.
#
# ![multi head attention](images/multi_head_attention.png)
#
# #### Questions:
#
# - In the **constructor**, create a list containing `num_heads` instances of the `Head` module using PyTorch’s [`ModuleList`](https://pytorch.org/docs/stable/generated/torch.nn.ModuleList.html).
# - In the `forward` function:
#   - Apply each **single-head attention** to the input.
#   - Concatenate the results using PyTorch’s [`cat`](https://pytorch.org/docs/stable/generated/torch.cat.html) function.

# %%
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size, embed_dim):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(num_heads * head_size, embed_dim)  # projection layer

    def forward(self, x):
        # apply each head and concatenate the results
        out = torch.cat([h(x) for h in self.heads], dim=-1)  # (B, T, num_heads * head_size)
        out = self.proj(out)  # (B, T, embed_dim) to mix the heads
        return out

# %% [markdown]
# #### Questions:
#
# 1. **Copy** the file `gpt_single_head.py` and rename it as `gpt_multi_head.py`.
# 2. **Add** the `MultiHeadAttention` module in `gpt_multi_head.py`.
# 3. At the **beginning of the file**, add a parameter:
#    ```python
#    n_head = 4
#    ```
# 4. In the `BigramLanguageModel` module, **replace** the `Head` module with `MultiHeadAttention`, using the parameters:
#    ```python
#    num_heads = n_head
#    head_size = n_embd // n_head
#    ```
#    This ensures the total number of parameters remains **the same**.
# 5. **Retrain the model** and note:
#    - The total number of **parameters**
#    - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.009893 M parameters
# step 4999: train loss 2.1570, val loss 2.1802
# ```

# %% [markdown]
# Outputs :
# 0.010949 M parameters
# step 4999: train loss 2.1652, val loss 2.1782

# %% [markdown]
# ## Adding a FeedForward Computation Layer
#
# After the **attention layers**, which collect information from the sequence, a **computation layer** is added to combine all the gathered information.
#
# This layer is a simple **Multi-Layer Perceptron (MLP)** with:
# - One **hidden layer**,
# - A **ReLU non-linearity** using [`ReLU`](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html).
#
# ### Architecture:
#
# <img src="images/multi_ff.png" alt="multi feedforward" width="200">

# %%
class FeedForward(nn.Module):
    """ a simple MLP with RELU """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_embd),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# #### Questions:
#
# 1. **Add** the `FeedForward` module to your `gpt_multi_head.py` file.
# 2. **Integrate** this `FeedForward` layer **after** the **multi-head attention** module.
# 3. **Retrain the model** and note:
#    - The total **number of parameters**
#    - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.010949 M parameters
# step 4999: train loss 2.1290, val loss 2.1216
# ```

# %% [markdown]
# Outputs :
# step 4999: train loss 2.0408, val loss 2.0547
# 0.019301 M parameters

# %% [markdown]
# ## Stacking Blocks
#
# The network we have built so far represents just **one block** of the final model. Now, we can **stack multiple blocks** of **multi-head attention** to create a **deeper** network.
#
# ### Architecture:
# ![multi feedforward](images/multi_bloc.png)
#
# The following code defines a **block**:

# %%
class Block(nn.Module):
    """ A single bloc of multi-head attention """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)

    def forward(self, x):
        x = self.sa(x)
        x = self.ffwd(x)
        return x

# %% [markdown]
# #### Questions:
#
# - Add the `Block` module to `gpt_multi_head.py`.
# - Modify the `BigramLanguageModel` code to include **three** instances of `Block(n_embd, n_head=4)`, using a [`Sequential`](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) container **instead of** `MultiHeadAttention` and `FeedForward`.
# - Retrain the model and note:
#   - The **number of parameters**
#   - The **training** and **validation** losses obtained
#
# **Expected Output Example:**
# ```
# 0.019205 M parameters
# step 4999: train loss 2.2080, val loss 2.2213
# ```

# %% [markdown]
# Outputs : step 4999: train loss 2.1871, val loss 2.2085
# 0.044261 M parameters

# %% [markdown]
# ## Improving Training
#
# If we want to continue increasing the **network size**, we need to incorporate layers that **enhance training stability** and **improve generalization** (reducing overfitting). These layers include:
#
# - **Skip connections** (or **residual connections**)
# - **Normalization layers**
# - **Dropout**
#
# ### Updated Architecture:
#
# <img src="images/multi_skip_norm.png" alt="multi feedforward" width="200">
#
# ---
#
# #### Questions:
#
# 1. In the `Block` module, **add a skip connection** by summing the input at each step:
#    ```python
#    x = x + self.sa(self.ln1(x))
#    x = x + self.ffwd(self.ln2(x))
#    ```
#
# 2. In the `Block` module, **add two** [`LayerNorm`](https://pytorch.org/docs/stable/generated/torch.nn.LayerNorm.html) layers of size `n_embd`:
#    - **Before** the `Multi-Head Attention` layer.
#    - **Before** the `FeedForward` layer.
#
# 3. **After the sequence of 3 blocks**, add a **LayerNorm** layer of size `n_embd`.
#
# 4. Define a variable at the **beginning of the file**:
#    ```python
#    dropout = 0.2
#    ```
#    Then add a [`Dropout`](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) layer:
#    - **After** the `ReLU` activation in `FeedForward`.
#    - **After** the `Multi-Head Attention` layer in `MultiHeadAttention`.
#    - **After** the `softmax` layer in the single-head attention `Head`.
#
# 5. **Retrain the model** and note:
#    - The **number of parameters**
#    - The **training** and **validation** losses
#
# ---
#
# **Expected Output Example:**
# ```
# 0.019653 M parameters
# ```

# %% [markdown]
# Output :
# step 4999: train loss 0.2767, val loss 0.2863
# 0.044709 M parameters

# %% [markdown]
# ## Conclusion
#
# The key components of **GPT-2** are now in place. The next step is to **scale up** the model and train it on a **much larger** dataset. For comparison, the parameters of [GPT-2](https://huggingface.co/transformers/v2.11.0/model_doc/gpt2.html) are:
#
# - **`vocab_size = 50257`** → GPT-2 models **subword tokens**, while we model **characters**. For us, `vocab_size = 100`.
# - **`n_positions = 1024`** → The maximum **context size**. For us, it's `block_size = 8`.
# - **`n_embd = 768`** → The **embedding dimension**. For us, it's `n_embd = 32`.
# - **`n_layer = 12`** → The number of **blocks**. For us, it's `3`.
# - **`n_head = 12`** → The number of **multi-head attention layers**. For us, it's `4`.
#
# Overall, **GPT-2** consists of **1.5 billion parameters** and was trained on **8 million web pages**, totaling **40 GB of text**.
#
# ---
#
# ### **Training Results**
# ```text
# 10.816613 M parameters
# step 0: train loss 4.7847, val loss 4.7701
# step 4999: train loss 0.2683, val loss 2.1161
# time: 31m47.910s
# ```
#
# ### **Generated Text Sample:**
#
# ```text
# Le pêcheur où l'homme en peu de Carevante
# Sa conter des chosses qu'en ses yoitn!
#
# Ils sont là-hauts parler à leurs ténèbres
# A ceux qu'on rêve aux oiseaux des cheveux,
# Et celus qu'on tourna jamais sous le front;
# Ils se disent tu mêle aux univers.
# J'ai vu Jean vu France, potte; petits contempler,
# Et petié calme au milibre et versait,
# M'éblouissant, emportant, écoute, ingorancessible,
# On meurt s'efferayait.....--Pas cont âme parle en Apparia!
# ```
